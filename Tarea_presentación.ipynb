# %% [markdown]
# # Título
# ## Subtítulo
# ###### Encabezado pequeño
#
# Ejemplo de párrafo `código dentro del párrafo` (acentos graves). Podemos escribir ecuaciones $\sum_{i}^{n}x_1^2+x_2^2=1^i$.
# ```python
# if
# for
# # comentarios en python
# a=1 # variable
# ```
# Ecuaciones fuera del texto:
# $$
# \nabla\cdot f=\frac{\partial}{\partial x_1}f+\frac{\partial}{\partial x_2}f+\cdots +\sum_{i}^{n}\frac{\partial}{\partial x_i}f
# $$
#
# Texto en **negritas** o __doble guión bajo__. Texto en *itálica* o con _un guión bajo_.
#
# Si queremos escribir en otro párrafo, debemos dar doble enter. ~Texto tachado~.
# * listas
# * elementos de listas
# - También podemos usar guiones.
#
# 1. Listas enumeradas
# 2. Otro elemento
# 2. Tercer elemento
#
# > Texto citado
